# %%
import scipy.io
import os
import numpy as np
import pandas as pd
import time
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import cohen_kappa_score
import Butterworth_filtering

from BW_metric import BW_dist
from AI_metric import AI_dist
from manifold_project_toolbox import F_dist
from manifold_project_toolbox import bw_projection_mean
from manifold_project_toolbox import ai_projection_mean
from manifold_project_toolbox import x2corr

from load_BCI_III_IVa import import_data

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" # enable multiple output in one cell

# %%
def MDM_dist(A, B, method):
    if method == "BW":
        output = BW_dist(A,B)
    elif method == "AI":
        output = AI_dist(A,B)
    elif method == "Euc":
        output = F_dist(A,B)
    return output

def MDM_mean(x, eps, method, verbose=False):
    # input: psd matrices [N,n,n]
    # output: mean matrix [n,n]
    if method == "BW":
        output = bw_projection_mean(x, eps, verbose=verbose)
    elif method == "AI":
        output = ai_projection_mean(x, eps, verbose=verbose)
    elif method == "Euc":
        output = np.mean(x, axis=0) # arithmetic mean
    return output

# %%
# BCI III IVa
subject = "aw"
data_train, data_test, label_train, label_test = import_data(subject, start_time=0.5, end_time=3)
data_train_filtered = Butterworth_filtering.filter_all(data_train, order=5, lowcut=8, highcut=30, fs=1000)

sample = x2corr(data_train_filtered)
label = label_train

sample.shape
label.shape
# Out:
# (56, 118, 118)
# (56,)

# %%
# parameter setting
method = "AI"
repetition = 10 # number of reps for cv
k = 6 # k-fold cv

accuracy = np.zeros((repetition, k), dtype = np.float32)
execution_time = np.zeros((repetition, k), dtype = np.float32)

for rep_idx in range(repetition):

    ##### k-fold split
    kfold = StratifiedKFold(n_splits=k, shuffle=True, random_state=rep_idx+22)
    x_train_kfold = []
    y_train_kfold = []
    x_test_kfold = []
    y_test_kfold = []
    for train_idx, test_idx in kfold.split(sample, label):
        x_train_kfold.append(sample[train_idx])
        y_train_kfold.append(label[train_idx])
        x_test_kfold.append(sample[test_idx])
        y_test_kfold.append(label[test_idx])

    ##### MDM
    for fold_idx in range(k):
        # choose fold
        x_train = x_train_kfold[fold_idx]
        y_train = y_train_kfold[fold_idx]
        x_test = x_test_kfold[fold_idx]
        y_test = y_test_kfold[fold_idx]
        # compute mean of each class
        start_time = time.time() # timer starts
        mean1 = MDM_mean(x_train[np.where(y_train==1)], 0.01, method, verbose=True)
        mean2 = MDM_mean(x_train[np.where(y_train==2)], 0.01, method, verbose=True)
        # assign each testing sample to the nearest class mean
        y_pred = np.zeros(x_test.shape[0], dtype = np.float32)
        for test_idx in range(x_test.shape[0]):
            dist1 = MDM_dist(mean1, x_test[test_idx], method)
            dist2 = MDM_dist(mean2, x_test[test_idx], method)
            y_pred[test_idx] = 1 if dist1<dist2 else 2
        end_time = time.time() # timer stops
        # record accuracy and execution time
        accuracy[rep_idx,fold_idx] = sum(y_pred==y_test)/len(y_test)
        execution_time[rep_idx,fold_idx] = end_time - start_time
        
        print("Fold " + str(fold_idx+1) + " completed.")
    print("Repetition " + str(rep_idx+1) + " completed.")
# Out:
# logm result may be inaccurate, approximate err = 6.355629388531736e-06
# logm result may be inaccurate, approximate err = 4.667407269557681e-06
# logm result may be inaccurate, approximate err = 4.038375989744293e-06
# logm result may be inaccurate, approximate err = 2.6305614152014085e-06
# logm result may be inaccurate, approximate err = 4.029201700914232e-06
# logm result may be inaccurate, approximate err = 1.759758096309629e-06
# logm result may be inaccurate, approximate err = 5.646699727573788e-06
# logm result may be inaccurate, approximate err = 4.840718593240053e-06
# logm result may be inaccurate, approximate err = 3.6735585449162743e-06
# logm result may be inaccurate, approximate err = 8.993446701562549e-06
# logm result may be inaccurate, approximate err = 6.357565118021894e-06
# logm result may be inaccurate, approximate err = 5.970629511457707e-06
# logm result may be inaccurate, approximate err = 4.879901037623255e-06
# logm result may be inaccurate, approximate err = 5.571135587427003e-06
# logm result may be inaccurate, approximate err = 3.5773488247338208e-06
# logm result may be inaccurate, approximate err = 4.317226303974602e-06
# logm result may be inaccurate, approximate err = 4.311652348111927e-06
# logm result may be inaccurate, approximate err = 4.052921123775123e-06
# logm result may be inaccurate, approximate err = 4.236384894400042e-06
# logm result may be inaccurate, approximate err = 3.6149211145074316e-06
# logm result may be inaccurate, approximate err = 3.981437820780218e-06
# logm result may be inaccurate, approximate err = 4.492644484867486e-06
# logm result may be inaccurate, approximate err = 4.855038418013987e-06
# logm result may be inaccurate, approximate err = 5.464436030170685e-06
# logm result may be inaccurate, approximate err = 1.8768239550433056e-06
# Iter0, Smaller step? NA, dist_mean=14.2817181
# Iter1, Smaller step? True, dist_mean=2.1842561
# Iter2, Smaller step? True, dist_mean=1.2643128
# Iter3, Smaller step? True, dist_mean=0.8412799
# Iter4, Smaller step? True, dist_mean=0.6055267
# Iter5, Smaller step? True, dist_mean=0.4605933
# Iter6, Smaller step? True, dist_mean=0.362326
# Iter7, Smaller step? True, dist_mean=0.2930681
# Iter8, Smaller step? True, dist_mean=0.2415655
# Iter9, Smaller step? True, dist_mean=0.2024922
# Iter10, Smaller step? True, dist_mean=0.1717946
# Iter11, Smaller step? True, dist_mean=0.1473684
# Iter12, Smaller step? True, dist_mean=0.1274527
# Iter13, Smaller step? True, dist_mean=0.1110706
# Iter14, Smaller step? True, dist_mean=0.0973578
# Iter15, Smaller step? True, dist_mean=0.0858059
# Iter16, Smaller step? True, dist_mean=0.0759497
# Iter17, Smaller step? True, dist_mean=0.0675004
# Iter18, Smaller step? True, dist_mean=0.0601882
# Iter19, Smaller step? True, dist_mean=0.053837
# Iter20, Smaller step? True, dist_mean=0.0482806
# Iter21, Smaller step? True, dist_mean=0.0434055
# Iter22, Smaller step? True, dist_mean=0.0391043
# Iter23, Smaller step? True, dist_mean=0.0353002
# Iter24, Smaller step? True, dist_mean=0.0319211
# Iter25, Smaller step? True, dist_mean=0.0289134
# Iter26, Smaller step? True, dist_mean=0.0262268
# Iter27, Smaller step? True, dist_mean=0.0238229
# Iter28, Smaller step? True, dist_mean=0.0216657
# Iter29, Smaller step? True, dist_mean=0.0197271
# Iter30, Smaller step? True, dist_mean=0.0179806
# Iter31, Smaller step? True, dist_mean=0.0164053
# Iter32, Smaller step? True, dist_mean=0.0149815
# Iter33, Smaller step? True, dist_mean=0.0136932
# Iter34, Smaller step? True, dist_mean=0.0125255
# Iter35, Smaller step? True, dist_mean=0.011466
# Iter36, Smaller step? True, dist_mean=0.0105034
# Iter37, Smaller step? True, dist_mean=0.009628
# logm result may be inaccurate, approximate err = 2.8904933388918866e-06
# logm result may be inaccurate, approximate err = 1.742925920918828e-06
# logm result may be inaccurate, approximate err = 7.107226237949116e-06
# logm result may be inaccurate, approximate err = 3.1619062230286047e-06
# logm result may be inaccurate, approximate err = 2.819899727122818e-06
# logm result may be inaccurate, approximate err = 7.068293014986322e-06
# logm result may be inaccurate, approximate err = 2.406846391416887e-06
# logm result may be inaccurate, approximate err = 3.562610496902214e-06
# logm result may be inaccurate, approximate err = 4.457715123334625e-06
# logm result may be inaccurate, approximate err = 4.660022055530399e-06
# logm result may be inaccurate, approximate err = 3.7280762824507266e-06
# logm result may be inaccurate, approximate err = 4.726398518345953e-06
# logm result may be inaccurate, approximate err = 2.643881701448874e-06
# logm result may be inaccurate, approximate err = 6.5528013384562905e-06
# logm result may be inaccurate, approximate err = 4.946893340864875e-06
# logm result may be inaccurate, approximate err = 5.706071622301164e-06
# logm result may be inaccurate, approximate err = 5.729805722753262e-06
# logm result may be inaccurate, approximate err = 3.7286625521785576e-06
# logm result may be inaccurate, approximate err = 2.7606727237917453e-06
# logm result may be inaccurate, approximate err = 4.03372707873628e-06
# logm result may be inaccurate, approximate err = 8.401635605203059e-06
# Iter0, Smaller step? NA, dist_mean=14.293988
# Iter1, Smaller step? True, dist_mean=2.3545256
# Iter2, Smaller step? True, dist_mean=1.4245467
# Iter3, Smaller step? True, dist_mean=0.9966038
# Iter4, Smaller step? True, dist_mean=0.7548702
# Iter5, Smaller step? True, dist_mean=0.6062623
# Iter6, Smaller step? True, dist_mean=0.5068334
# Iter7, Smaller step? True, dist_mean=0.440493
# Iter8, Smaller step? True, dist_mean=0.3962361
# Iter9, Smaller step? True, dist_mean=0.3694494
# Iter10, Smaller step? True, dist_mean=0.3561484
# Iter11, Smaller step? True, dist_mean=0.3542955
# Iter12, Smaller step? False, dist_mean=0.3619792
# Fold 1 completed.
# logm result may be inaccurate, approximate err = 5.0401232688458746e-06
# logm result may be inaccurate, approximate err = 4.4356021691107894e-06
# logm result may be inaccurate, approximate err = 4.038083973310323e-06
# logm result may be inaccurate, approximate err = 2.9426370490666615e-06
# logm result may be inaccurate, approximate err = 2.880371537824794e-06
# logm result may be inaccurate, approximate err = 4.617949184161389e-06
# logm result may be inaccurate, approximate err = 4.367149804981481e-06
# logm result may be inaccurate, approximate err = 2.6450791605573537e-06
# logm result may be inaccurate, approximate err = 5.382490096786433e-06
# logm result may be inaccurate, approximate err = 3.3410470587683577e-06
# logm result may be inaccurate, approximate err = 6.42787166270592e-06
# logm result may be inaccurate, approximate err = 3.4856645635321326e-06
# logm result may be inaccurate, approximate err = 4.913205617645529e-06
# logm result may be inaccurate, approximate err = 4.682585448419793e-06
# logm result may be inaccurate, approximate err = 3.0963220027979574e-06
# logm result may be inaccurate, approximate err = 4.997410259105409e-06
# logm result may be inaccurate, approximate err = 5.128006651343548e-06
# logm result may be inaccurate, approximate err = 3.779107895229711e-06
# logm result may be inaccurate, approximate err = 4.26653808681444e-06
# logm result may be inaccurate, approximate err = 4.961787371994013e-06
# logm result may be inaccurate, approximate err = 5.312037312199311e-06
# logm result may be inaccurate, approximate err = 2.5770864039430113e-06
# logm result may be inaccurate, approximate err = 4.763469183623572e-06
# logm result may be inaccurate, approximate err = 3.893213350047318e-06
# logm result may be inaccurate, approximate err = 1.6973780169074987e-06
# Iter0, Smaller step? NA, dist_mean=14.1114847
# Iter1, Smaller step? True, dist_mean=2.1874119
# Iter2, Smaller step? True, dist_mean=1.2729264
# Iter3, Smaller step? True, dist_mean=0.8511745
# Iter4, Smaller step? True, dist_mean=0.615138
# Iter5, Smaller step? True, dist_mean=0.4694369
# Iter6, Smaller step? True, dist_mean=0.370276
# Iter7, Smaller step? True, dist_mean=0.3001522
# Iter8, Smaller step? True, dist_mean=0.2478966
# Iter9, Smaller step? True, dist_mean=0.2081906
# Iter10, Smaller step? True, dist_mean=0.1770001
# Iter11, Smaller step? True, dist_mean=0.1522018
# Iter12, Smaller step? True, dist_mean=0.132028
# Iter13, Smaller step? True, dist_mean=0.1154823
# Iter14, Smaller step? True, dist_mean=0.1016865
# Iter15, Smaller step? True, dist_mean=0.0901184
# Iter16, Smaller step? True, dist_mean=0.0803004
# Iter17, Smaller step? True, dist_mean=0.0719346
# Iter18, Smaller step? True, dist_mean=0.0647422
# Iter19, Smaller step? True, dist_mean=0.0585413
# Iter20, Smaller step? True, dist_mean=0.0531591
# Iter21, Smaller step? True, dist_mean=0.048478
# Iter22, Smaller step? True, dist_mean=0.0443857
# Iter23, Smaller step? True, dist_mean=0.0408023
# Iter24, Smaller step? True, dist_mean=0.0376517
# Iter25, Smaller step? True, dist_mean=0.0348777
# Iter26, Smaller step? True, dist_mean=0.0324267
# Iter27, Smaller step? True, dist_mean=0.030258
# Iter28, Smaller step? True, dist_mean=0.0283329
# Iter29, Smaller step? True, dist_mean=0.0266213
# Iter30, Smaller step? True, dist_mean=0.0250947
# Iter31, Smaller step? True, dist_mean=0.0237304
# Iter32, Smaller step? True, dist_mean=0.0225074
# Iter33, Smaller step? True, dist_mean=0.0214084
# Iter34, Smaller step? True, dist_mean=0.0204175
# Iter35, Smaller step? True, dist_mean=0.0195217
# Iter36, Smaller step? True, dist_mean=0.0187089
# Iter37, Smaller step? True, dist_mean=0.0179694
# Iter38, Smaller step? True, dist_mean=0.0172941
# Iter39, Smaller step? True, dist_mean=0.0166753
# Iter40, Smaller step? True, dist_mean=0.0161064
# Iter41, Smaller step? True, dist_mean=0.0155814
# Iter42, Smaller step? True, dist_mean=0.0150954
# Iter43, Smaller step? True, dist_mean=0.0146439
# Iter44, Smaller step? True, dist_mean=0.0142229
# Iter45, Smaller step? True, dist_mean=0.0138293
# Iter46, Smaller step? True, dist_mean=0.0134599
# Iter47, Smaller step? True, dist_mean=0.0131123
# Iter48, Smaller step? True, dist_mean=0.0127841
# Iter49, Smaller step? True, dist_mean=0.0124735
# Iter50, Smaller step? True, dist_mean=0.0121787
# Iter51, Smaller step? True, dist_mean=0.0118982
# Iter52, Smaller step? True, dist_mean=0.0116306
# Iter53, Smaller step? True, dist_mean=0.0113748
# Iter54, Smaller step? True, dist_mean=0.0111297
# Iter55, Smaller step? True, dist_mean=0.0108944
# Iter56, Smaller step? True, dist_mean=0.0106681
# Iter57, Smaller step? True, dist_mean=0.0104502
# Iter58, Smaller step? True, dist_mean=0.0102398
# Iter59, Smaller step? True, dist_mean=0.0100366
# Iter60, Smaller step? True, dist_mean=0.0098398
# logm result may be inaccurate, approximate err = 2.1152701480031997e-06
# logm result may be inaccurate, approximate err = 5.372591098787378e-06
# logm result may be inaccurate, approximate err = 4.028855341423344e-06
# logm result may be inaccurate, approximate err = 3.6106808613477095e-06
# logm result may be inaccurate, approximate err = 3.684482754528429e-06
# logm result may be inaccurate, approximate err = 5.3632454035047726e-06
# logm result may be inaccurate, approximate err = 2.9119770587971603e-06
# logm result may be inaccurate, approximate err = 4.917379403057464e-06
# logm result may be inaccurate, approximate err = 3.401435722099904e-06
# logm result may be inaccurate, approximate err = 6.643411648354381e-06
# logm result may be inaccurate, approximate err = 6.056485718440864e-06
# logm result may be inaccurate, approximate err = 5.340738212143795e-06
# logm result may be inaccurate, approximate err = 4.614675288740634e-06
# logm result may be inaccurate, approximate err = 6.27549895924491e-06
# logm result may be inaccurate, approximate err = 2.694662793994159e-06
# logm result may be inaccurate, approximate err = 2.966414564313497e-06
# logm result may be inaccurate, approximate err = 3.529495546090653e-06
# logm result may be inaccurate, approximate err = 5.643299807016632e-06
# logm result may be inaccurate, approximate err = 5.115626814323415e-06
# logm result may be inaccurate, approximate err = 3.2583903301837726e-06
# logm result may be inaccurate, approximate err = 3.4587445914349778e-06
# Iter0, Smaller step? NA, dist_mean=14.1285539
# Iter1, Smaller step? True, dist_mean=2.2945041
# Iter2, Smaller step? True, dist_mean=1.3856369
# Iter3, Smaller step? True, dist_mean=0.9645365
# Iter4, Smaller step? True, dist_mean=0.7233048
# Iter5, Smaller step? True, dist_mean=0.5709521
# Iter6, Smaller step? True, dist_mean=0.4646823
# Iter7, Smaller step? True, dist_mean=0.3884242
# Iter8, Smaller step? True, dist_mean=0.3310987
# Iter9, Smaller step? True, dist_mean=0.2880172
# Iter10, Smaller step? True, dist_mean=0.2551924
# Iter11, Smaller step? True, dist_mean=0.2308822
# Iter12, Smaller step? True, dist_mean=0.2134185
# Iter13, Smaller step? True, dist_mean=0.2020405
# Iter14, Smaller step? True, dist_mean=0.1959356
# Iter15, Smaller step? True, dist_mean=0.1946432
# Iter16, Smaller step? False, dist_mean=0.1976499
# Fold 2 completed.
# logm result may be inaccurate, approximate err = 5.162301334736582e-06
# logm result may be inaccurate, approximate err = 4.026075961906171e-06
# logm result may be inaccurate, approximate err = 4.319861070309939e-06
# logm result may be inaccurate, approximate err = 4.784348363651615e-06
# logm result may be inaccurate, approximate err = 6.074618891079059e-06
# logm result may be inaccurate, approximate err = 3.2860724730838543e-06
# logm result may be inaccurate, approximate err = 7.549838295102929e-06
# logm result may be inaccurate, approximate err = 2.041933034861772e-06
# logm result may be inaccurate, approximate err = 4.1722878694629e-06
# logm result may be inaccurate, approximate err = 7.547035793747089e-06
# logm result may be inaccurate, approximate err = 4.692517674505005e-06
# logm result may be inaccurate, approximate err = 6.398776477649728e-06
# logm result may be inaccurate, approximate err = 4.951314190186409e-06
# logm result may be inaccurate, approximate err = 4.776340801138681e-06
# logm result may be inaccurate, approximate err = 3.5640030472205553e-06
# logm result may be inaccurate, approximate err = 3.7776939899420658e-06
# logm result may be inaccurate, approximate err = 3.278418543534808e-06
# logm result may be inaccurate, approximate err = 3.519186033947066e-06
# logm result may be inaccurate, approximate err = 3.885499411571187e-06
# logm result may be inaccurate, approximate err = 5.1033887654864755e-06
# logm result may be inaccurate, approximate err = 5.64605943610306e-06
# logm result may be inaccurate, approximate err = 3.6288443311981603e-06
# logm result may be inaccurate, approximate err = 2.921082818588798e-06
# logm result may be inaccurate, approximate err = 3.398962179698852e-06
# logm result may be inaccurate, approximate err = 2.7526965077787503e-06
# Iter0, Smaller step? NA, dist_mean=14.1090253
# Iter1, Smaller step? True, dist_mean=2.168663
# Iter2, Smaller step? True, dist_mean=1.263917
# Iter3, Smaller step? True, dist_mean=0.84162
# Iter4, Smaller step? True, dist_mean=0.6033409
# Iter5, Smaller step? True, dist_mean=0.455423
# Iter6, Smaller step? True, dist_mean=0.354345
# Iter7, Smaller step? True, dist_mean=0.2827374
# Iter8, Smaller step? True, dist_mean=0.2294189
# Iter9, Smaller step? True, dist_mean=0.1890625
# Iter10, Smaller step? True, dist_mean=0.1575686
# Iter11, Smaller step? True, dist_mean=0.1327648
# Iter12, Smaller step? True, dist_mean=0.1128223
# Iter13, Smaller step? True, dist_mean=0.0966949
# Iter14, Smaller step? True, dist_mean=0.0834593
# Iter15, Smaller step? True, dist_mean=0.0725521
# Iter16, Smaller step? True, dist_mean=0.063464
# Iter17, Smaller step? True, dist_mean=0.0558661
# Iter18, Smaller step? True, dist_mean=0.0494579
# Iter19, Smaller step? True, dist_mean=0.0440359
# Iter20, Smaller step? True, dist_mean=0.0394136
# Iter21, Smaller step? True, dist_mean=0.0354598
# Iter22, Smaller step? True, dist_mean=0.0320545
# Iter23, Smaller step? True, dist_mean=0.0291108
# Iter24, Smaller step? True, dist_mean=0.0265493
# Iter25, Smaller step? True, dist_mean=0.0243115
# Iter26, Smaller step? True, dist_mean=0.0223443
# Iter27, Smaller step? True, dist_mean=0.0206074
# Iter28, Smaller step? True, dist_mean=0.0190649
# Iter29, Smaller step? True, dist_mean=0.0176892
# Iter30, Smaller step? True, dist_mean=0.0164555
# Iter31, Smaller step? True, dist_mean=0.0153446
# Iter32, Smaller step? True, dist_mean=0.0143395
# Iter33, Smaller step? True, dist_mean=0.0134267
# Iter34, Smaller step? True, dist_mean=0.0125942
# Iter35, Smaller step? True, dist_mean=0.0118326
# Iter36, Smaller step? True, dist_mean=0.0111331
# Iter37, Smaller step? True, dist_mean=0.0104891
# Iter38, Smaller step? True, dist_mean=0.0098943
# logm result may be inaccurate, approximate err = 4.1570096117999815e-06
# logm result may be inaccurate, approximate err = 9.615381505914334e-06
# logm result may be inaccurate, approximate err = 3.0197313927216073e-06
# logm result may be inaccurate, approximate err = 3.167281064971192e-06
# logm result may be inaccurate, approximate err = 2.3842163339462076e-06
# logm result may be inaccurate, approximate err = 4.3564343683465005e-06
# logm result may be inaccurate, approximate err = 5.395425947858616e-06
# logm result may be inaccurate, approximate err = 3.900053400556969e-06
# logm result may be inaccurate, approximate err = 1.0196731498671046e-05
# logm result may be inaccurate, approximate err = 4.972569522830149e-06
# logm result may be inaccurate, approximate err = 5.243363461403264e-06
# logm result may be inaccurate, approximate err = 4.1187719607862645e-06
# logm result may be inaccurate, approximate err = 4.867032953730775e-06
# logm result may be inaccurate, approximate err = 5.503398782757803e-06
# logm result may be inaccurate, approximate err = 6.836495257924594e-06
# logm result may be inaccurate, approximate err = 2.4978005186688456e-06
# logm result may be inaccurate, approximate err = 4.726815200356008e-06
# logm result may be inaccurate, approximate err = 2.821079136878979e-06
# logm result may be inaccurate, approximate err = 4.65002604465231e-06
# logm result may be inaccurate, approximate err = 8.863122619669853e-06
# logm result may be inaccurate, approximate err = 4.431061878108663e-06
# logm result may be inaccurate, approximate err = 2.806316062764671e-06
# Iter0, Smaller step? NA, dist_mean=14.037238
# Iter1, Smaller step? True, dist_mean=2.2319645
# Iter2, Smaller step? True, dist_mean=1.351612
# Iter3, Smaller step? True, dist_mean=0.9420619
# Iter4, Smaller step? True, dist_mean=0.7092476
# Iter5, Smaller step? True, dist_mean=0.5637413
# Iter6, Smaller step? True, dist_mean=0.4634545
# Iter7, Smaller step? True, dist_mean=0.3923602
# Iter8, Smaller step? True, dist_mean=0.3394642
# Iter9, Smaller step? True, dist_mean=0.3001362
# Iter10, Smaller step? True, dist_mean=0.27038
# Iter11, Smaller step? True, dist_mean=0.2484782
# Iter12, Smaller step? True, dist_mean=0.2327123
# Iter13, Smaller step? True, dist_mean=0.2223377
# Iter14, Smaller step? True, dist_mean=0.2165316
# Iter15, Smaller step? True, dist_mean=0.2149121
# Iter16, Smaller step? False, dist_mean=0.21705
# Fold 3 completed.
# logm result may be inaccurate, approximate err = 7.888162818091054e-06
# logm result may be inaccurate, approximate err = 3.950133158589951e-06
# logm result may be inaccurate, approximate err = 4.381849366250578e-06
# logm result may be inaccurate, approximate err = 4.541842965106661e-06
# logm result may be inaccurate, approximate err = 3.343238229330364e-06
# logm result may be inaccurate, approximate err = 4.225194827736833e-06
# logm result may be inaccurate, approximate err = 2.241000721953806e-06
# logm result may be inaccurate, approximate err = 6.5647197341845226e-06
# logm result may be inaccurate, approximate err = 3.234152189930022e-06
# logm result may be inaccurate, approximate err = 6.110794538750286e-06
# logm result may be inaccurate, approximate err = 3.912177544799986e-06
# logm result may be inaccurate, approximate err = 4.590255231827602e-06
# logm result may be inaccurate, approximate err = 3.969731886657629e-06
# logm result may be inaccurate, approximate err = 2.868158610679447e-06
# logm result may be inaccurate, approximate err = 2.4081785438156176e-06
# logm result may be inaccurate, approximate err = 2.5025442014381006e-06
# logm result may be inaccurate, approximate err = 4.636271205496828e-06
# logm result may be inaccurate, approximate err = 4.140372980544049e-06
# logm result may be inaccurate, approximate err = 3.3903651295654997e-06
# logm result may be inaccurate, approximate err = 7.017314620267467e-06
# logm result may be inaccurate, approximate err = 2.2555793216368967e-06
# logm result may be inaccurate, approximate err = 3.945224472051895e-06
# logm result may be inaccurate, approximate err = 8.171052432307372e-06
# logm result may be inaccurate, approximate err = 2.4224860254805448e-06
# logm result may be inaccurate, approximate err = 1.6952306352151855e-06
# Iter0, Smaller step? NA, dist_mean=14.1433687
# Iter1, Smaller step? True, dist_mean=2.1937644
# Iter2, Smaller step? True, dist_mean=1.2790441
# Iter3, Smaller step? True, dist_mean=0.8536226
# Iter4, Smaller step? True, dist_mean=0.6137637
# Iter5, Smaller step? True, dist_mean=0.4654521
# Iter6, Smaller step? True, dist_mean=0.364993
# Iter7, Smaller step? True, dist_mean=0.2948716
# Iter8, Smaller step? True, dist_mean=0.2436275
# Iter9, Smaller step? True, dist_mean=0.2057097
# Iter10, Smaller step? True, dist_mean=0.1768004
# Iter11, Smaller step? True, dist_mean=0.1545733
# Iter12, Smaller step? True, dist_mean=0.1370671
# Iter13, Smaller step? True, dist_mean=0.1231636
# Iter14, Smaller step? True, dist_mean=0.1118804
# Iter15, Smaller step? True, dist_mean=0.1026444
# Iter16, Smaller step? True, dist_mean=0.0949365
# Iter17, Smaller step? True, dist_mean=0.0884534
# Iter18, Smaller step? True, dist_mean=0.0829108
# Iter19, Smaller step? True, dist_mean=0.0781444
# Iter20, Smaller step? True, dist_mean=0.0739929
# Iter21, Smaller step? True, dist_mean=0.0703651
# Iter22, Smaller step? True, dist_mean=0.0671658
# Iter23, Smaller step? True, dist_mean=0.0643428
# Iter24, Smaller step? True, dist_mean=0.0618375
# Iter25, Smaller step? True, dist_mean=0.0596185
# Iter26, Smaller step? True, dist_mean=0.0576482
# Iter27, Smaller step? True, dist_mean=0.0559067
# Iter28, Smaller step? True, dist_mean=0.0543687
# Iter29, Smaller step? True, dist_mean=0.0530207
# Iter30, Smaller step? True, dist_mean=0.0518445
# Iter31, Smaller step? True, dist_mean=0.0508305
# Iter32, Smaller step? True, dist_mean=0.0499649
# Iter33, Smaller step? True, dist_mean=0.0492403
# Iter34, Smaller step? True, dist_mean=0.0486458
# Iter35, Smaller step? True, dist_mean=0.0481749
# Iter36, Smaller step? True, dist_mean=0.047819
# Iter37, Smaller step? True, dist_mean=0.0475722
# Iter38, Smaller step? True, dist_mean=0.0474272
# Iter39, Smaller step? False, dist_mean=0.047379
# logm result may be inaccurate, approximate err = 3.6497905813852533e-06
# logm result may be inaccurate, approximate err = 2.0395261132199925e-06
# logm result may be inaccurate, approximate err = 6.072366050758955e-06
# logm result may be inaccurate, approximate err = 2.4249932395772015e-06
# logm result may be inaccurate, approximate err = 6.442733274989133e-06
# logm result may be inaccurate, approximate err = 6.2212813749020965e-06
# logm result may be inaccurate, approximate err = 3.3505873124403664e-06
# logm result may be inaccurate, approximate err = 3.726114043093529e-06
# logm result may be inaccurate, approximate err = 4.985703823701924e-06
# logm result may be inaccurate, approximate err = 4.171289311414093e-06
# logm result may be inaccurate, approximate err = 4.919900932462754e-06
# logm result may be inaccurate, approximate err = 5.743560252339733e-06
# logm result may be inaccurate, approximate err = 5.732740867988546e-06
# logm result may be inaccurate, approximate err = 2.8958530374516285e-06
# logm result may be inaccurate, approximate err = 5.136157382229218e-06
# logm result may be inaccurate, approximate err = 3.16925376482985e-06
# logm result may be inaccurate, approximate err = 5.422079763734215e-06
# logm result may be inaccurate, approximate err = 2.7269757001491086e-06
# logm result may be inaccurate, approximate err = 5.920321323778645e-06
# logm result may be inaccurate, approximate err = 5.1475935963726595e-06
# logm result may be inaccurate, approximate err = 4.96085479044721e-06
# logm result may be inaccurate, approximate err = 7.3182445451589955e-06
# Iter0, Smaller step? NA, dist_mean=14.2855233
# Iter1, Smaller step? True, dist_mean=2.3025477
# Iter2, Smaller step? True, dist_mean=1.3839367
# Iter3, Smaller step? True, dist_mean=0.9629823
# Iter4, Smaller step? True, dist_mean=0.7262013
# Iter5, Smaller step? True, dist_mean=0.580162
# Iter6, Smaller step? True, dist_mean=0.4817165
# Iter7, Smaller step? True, dist_mean=0.414849
# Iter8, Smaller step? True, dist_mean=0.3690505
# Iter9, Smaller step? True, dist_mean=0.3399508
# Iter10, Smaller step? True, dist_mean=0.3240028
# Iter11, Smaller step? True, dist_mean=0.3194475
# Iter12, Smaller step? False, dist_mean=0.3246231
# Fold 4 completed.
# logm result may be inaccurate, approximate err = 5.707597522681107e-06
# logm result may be inaccurate, approximate err = 5.254479795217303e-06
# logm result may be inaccurate, approximate err = 4.388302923141337e-06
# logm result may be inaccurate, approximate err = 2.8770202757879894e-06
# logm result may be inaccurate, approximate err = 4.181056149548392e-06
# logm result may be inaccurate, approximate err = 1.8833022374461924e-06
# logm result may be inaccurate, approximate err = 3.839453690094652e-06
# logm result may be inaccurate, approximate err = 5.223622822902332e-06
# logm result may be inaccurate, approximate err = 5.656631612963191e-06
# logm result may be inaccurate, approximate err = 6.376413313107427e-06
# logm result may be inaccurate, approximate err = 6.723236737096733e-06
# logm result may be inaccurate, approximate err = 6.5922442825379435e-06
# logm result may be inaccurate, approximate err = 3.430841425064299e-06
# logm result may be inaccurate, approximate err = 4.140175705676597e-06
# logm result may be inaccurate, approximate err = 3.280263971982037e-06
# logm result may be inaccurate, approximate err = 2.9252190919106484e-06
# logm result may be inaccurate, approximate err = 3.9158378066697676e-06
# logm result may be inaccurate, approximate err = 2.4090182711350755e-06
# logm result may be inaccurate, approximate err = 4.0022222877692e-06
# logm result may be inaccurate, approximate err = 3.5520234241336464e-06
# logm result may be inaccurate, approximate err = 6.0359322628951694e-06
# logm result may be inaccurate, approximate err = 4.184132907507575e-06
# logm result may be inaccurate, approximate err = 2.6670507777102087e-06
# logm result may be inaccurate, approximate err = 4.414516850488039e-06
# logm result may be inaccurate, approximate err = 3.9682647638028966e-06
# Iter0, Smaller step? NA, dist_mean=14.2729464
# Iter1, Smaller step? True, dist_mean=2.1729858
# Iter2, Smaller step? True, dist_mean=1.2645326
# Iter3, Smaller step? True, dist_mean=0.8386189
# Iter4, Smaller step? True, dist_mean=0.5972217
# Iter5, Smaller step? True, dist_mean=0.4470172
# Iter6, Smaller step? True, dist_mean=0.3448032
# Iter7, Smaller step? True, dist_mean=0.2727193
# Iter8, Smaller step? True, dist_mean=0.2194957
# Iter9, Smaller step? True, dist_mean=0.1794884
# Iter10, Smaller step? True, dist_mean=0.1485639
# Iter11, Smaller step? True, dist_mean=0.1243989
# Iter12, Smaller step? True, dist_mean=0.1051625
# Iter13, Smaller step? True, dist_mean=0.089737
# Iter14, Smaller step? True, dist_mean=0.077205
# Iter15, Smaller step? True, dist_mean=0.0669683
# Iter16, Smaller step? True, dist_mean=0.058524
# Iter17, Smaller step? True, dist_mean=0.0515266
# Iter18, Smaller step? True, dist_mean=0.0456811
# Iter19, Smaller step? True, dist_mean=0.0407765
# Iter20, Smaller step? True, dist_mean=0.036631
# Iter21, Smaller step? True, dist_mean=0.0331108
# Iter22, Smaller step? True, dist_mean=0.0300999
# Iter23, Smaller step? True, dist_mean=0.0275112
# Iter24, Smaller step? True, dist_mean=0.0252691
# Iter25, Smaller step? True, dist_mean=0.0233161
# Iter26, Smaller step? True, dist_mean=0.0216023
# Iter27, Smaller step? True, dist_mean=0.0200894
# Iter28, Smaller step? True, dist_mean=0.0187443
# Iter29, Smaller step? True, dist_mean=0.0175412
# Iter30, Smaller step? True, dist_mean=0.0164579
# Iter31, Smaller step? True, dist_mean=0.0154773
# Iter32, Smaller step? True, dist_mean=0.0145842
# Iter33, Smaller step? True, dist_mean=0.0137669
# Iter34, Smaller step? True, dist_mean=0.0130153
# Iter35, Smaller step? True, dist_mean=0.0123213
# Iter36, Smaller step? True, dist_mean=0.0116777
# Iter37, Smaller step? True, dist_mean=0.011079
# Iter38, Smaller step? True, dist_mean=0.0105201
# Iter39, Smaller step? True, dist_mean=0.0099971
# logm result may be inaccurate, approximate err = 4.450218543288249e-06
# logm result may be inaccurate, approximate err = 2.2376999510967643e-06
# logm result may be inaccurate, approximate err = 6.7887667926289575e-06
# logm result may be inaccurate, approximate err = 3.6125743072436452e-06
# logm result may be inaccurate, approximate err = 4.1782546237072426e-06
# logm result may be inaccurate, approximate err = 3.6055588987910475e-06
# logm result may be inaccurate, approximate err = 4.599457154395401e-06
# logm result may be inaccurate, approximate err = 2.5545760665244873e-06
# logm result may be inaccurate, approximate err = 5.247019683306969e-06
# logm result may be inaccurate, approximate err = 4.643817704919666e-06
# logm result may be inaccurate, approximate err = 3.5666415166209697e-06
# logm result may be inaccurate, approximate err = 4.2140766252878856e-06
# logm result may be inaccurate, approximate err = 3.023640289370574e-06
# logm result may be inaccurate, approximate err = 9.56187990437375e-06
# logm result may be inaccurate, approximate err = 1.833480546268379e-06
# logm result may be inaccurate, approximate err = 4.973800282150551e-06
# logm result may be inaccurate, approximate err = 4.040463801659842e-06
# logm result may be inaccurate, approximate err = 7.747719777836733e-06
# logm result may be inaccurate, approximate err = 3.845408772749923e-06
# logm result may be inaccurate, approximate err = 4.967926403971889e-06
# logm result may be inaccurate, approximate err = 2.902047090546519e-06
# logm result may be inaccurate, approximate err = 5.844950115208615e-06
# Iter0, Smaller step? NA, dist_mean=14.2616881
# Iter1, Smaller step? True, dist_mean=2.3275407
# Iter2, Smaller step? True, dist_mean=1.392789
# Iter3, Smaller step? True, dist_mean=0.9618927
# Iter4, Smaller step? True, dist_mean=0.7180279
# Iter5, Smaller step? True, dist_mean=0.5668703
# Iter6, Smaller step? True, dist_mean=0.4644946
# Iter7, Smaller step? True, dist_mean=0.3943703
# Iter8, Smaller step? True, dist_mean=0.3454929
# Iter9, Smaller step? True, dist_mean=0.3133279
# Iter10, Smaller step? True, dist_mean=0.2942883
# Iter11, Smaller step? True, dist_mean=0.2869107
# Iter12, Smaller step? False, dist_mean=0.2899244
# Fold 5 completed.
# logm result may be inaccurate, approximate err = 3.326319337993629e-06
# logm result may be inaccurate, approximate err = 3.547398865709966e-06
# logm result may be inaccurate, approximate err = 5.055203068263714e-06
# logm result may be inaccurate, approximate err = 3.220234178270338e-06
# logm result may be inaccurate, approximate err = 3.977161681251091e-06
# logm result may be inaccurate, approximate err = 2.074337745675313e-06
# logm result may be inaccurate, approximate err = 3.923889478185052e-06
# logm result may be inaccurate, approximate err = 6.7847305736819355e-06
# logm result may be inaccurate, approximate err = 5.0637786704950175e-06
# logm result may be inaccurate, approximate err = 3.624106719972666e-06
# logm result may be inaccurate, approximate err = 7.256405730671618e-06
# logm result may be inaccurate, approximate err = 3.867462645868274e-06
# logm result may be inaccurate, approximate err = 4.245819277386635e-06
# logm result may be inaccurate, approximate err = 8.676209832988185e-06
# logm result may be inaccurate, approximate err = 2.4042124175694783e-06
# logm result may be inaccurate, approximate err = 5.370267252875943e-06
# logm result may be inaccurate, approximate err = 4.8545838476528655e-06
# logm result may be inaccurate, approximate err = 2.680248645201247e-06
# logm result may be inaccurate, approximate err = 5.3990273925743135e-06
# logm result may be inaccurate, approximate err = 3.816357056346302e-06
# logm result may be inaccurate, approximate err = 4.456532868687166e-06
# logm result may be inaccurate, approximate err = 2.0544842604333023e-06
# logm result may be inaccurate, approximate err = 4.731323105801035e-06
# logm result may be inaccurate, approximate err = 4.477528359730538e-06
# logm result may be inaccurate, approximate err = 3.3434739014258415e-06
# Iter0, Smaller step? NA, dist_mean=14.1260219
# Iter1, Smaller step? True, dist_mean=2.1977651
# Iter2, Smaller step? True, dist_mean=1.2843194
# Iter3, Smaller step? True, dist_mean=0.865127
# Iter4, Smaller step? True, dist_mean=0.6312033
# Iter5, Smaller step? True, dist_mean=0.4872157
# Iter6, Smaller step? True, dist_mean=0.3890323
# Iter7, Smaller step? True, dist_mean=0.3195014
# Iter8, Smaller step? True, dist_mean=0.2674481
# Iter9, Smaller step? True, dist_mean=0.2277747
# Iter10, Smaller step? True, dist_mean=0.1964367
# Iter11, Smaller step? True, dist_mean=0.1714225
# Iter12, Smaller step? True, dist_mean=0.1509468
# Iter13, Smaller step? True, dist_mean=0.1340723
# Iter14, Smaller step? True, dist_mean=0.1199052
# Iter15, Smaller step? True, dist_mean=0.1079559
# Iter16, Smaller step? True, dist_mean=0.0977341
# Iter17, Smaller step? True, dist_mean=0.0889605
# Iter18, Smaller step? True, dist_mean=0.0813467
# Iter19, Smaller step? True, dist_mean=0.074722
# Iter20, Smaller step? True, dist_mean=0.0689067
# Iter21, Smaller step? True, dist_mean=0.0637907
# Iter22, Smaller step? True, dist_mean=0.0592571
# Iter23, Smaller step? True, dist_mean=0.0552319
# Iter24, Smaller step? True, dist_mean=0.0516361
# Iter25, Smaller step? True, dist_mean=0.0484181
# Iter26, Smaller step? True, dist_mean=0.0455232
# Iter27, Smaller step? True, dist_mean=0.0429145
# Iter28, Smaller step? True, dist_mean=0.0405531
# Iter29, Smaller step? True, dist_mean=0.0384118
# Iter30, Smaller step? True, dist_mean=0.0364626
# Iter31, Smaller step? True, dist_mean=0.0346852
# Iter32, Smaller step? True, dist_mean=0.0330587
# Iter33, Smaller step? True, dist_mean=0.031568
# Iter34, Smaller step? True, dist_mean=0.0301974
# Iter35, Smaller step? True, dist_mean=0.0289351
# Iter36, Smaller step? True, dist_mean=0.0277692
# Iter37, Smaller step? True, dist_mean=0.0266906
# Iter38, Smaller step? True, dist_mean=0.0256901
# Iter39, Smaller step? True, dist_mean=0.0247606
# Iter40, Smaller step? True, dist_mean=0.0238949
# Iter41, Smaller step? True, dist_mean=0.0230872
# Iter42, Smaller step? True, dist_mean=0.0223319
# Iter43, Smaller step? True, dist_mean=0.0216245
# Iter44, Smaller step? True, dist_mean=0.0209605
# Iter45, Smaller step? True, dist_mean=0.0203362
# Iter46, Smaller step? True, dist_mean=0.0197479
# Iter47, Smaller step? True, dist_mean=0.0191928
# Iter48, Smaller step? True, dist_mean=0.0186679
# Iter49, Smaller step? True, dist_mean=0.0181708
# Iter50, Smaller step? True, dist_mean=0.0176992
# Iter51, Smaller step? True, dist_mean=0.0172509
# Iter52, Smaller step? True, dist_mean=0.0168242
# Iter53, Smaller step? True, dist_mean=0.0164174
# Iter54, Smaller step? True, dist_mean=0.0160289
# Iter55, Smaller step? True, dist_mean=0.0156574
# Iter56, Smaller step? True, dist_mean=0.0153015
# Iter57, Smaller step? True, dist_mean=0.0149602
# Iter58, Smaller step? True, dist_mean=0.0146323
# Iter59, Smaller step? True, dist_mean=0.0143171
# Iter60, Smaller step? True, dist_mean=0.0140135
# Iter61, Smaller step? True, dist_mean=0.0137208
# Iter62, Smaller step? True, dist_mean=0.0134383
# Iter63, Smaller step? True, dist_mean=0.0131653
# Iter64, Smaller step? True, dist_mean=0.0129013
# Iter65, Smaller step? True, dist_mean=0.0126456
# Iter66, Smaller step? True, dist_mean=0.0123978
# Iter67, Smaller step? True, dist_mean=0.0121575
# Iter68, Smaller step? True, dist_mean=0.0119241
# Iter69, Smaller step? True, dist_mean=0.0116973
# Iter70, Smaller step? True, dist_mean=0.0114768
# Iter71, Smaller step? True, dist_mean=0.0112622
# Iter72, Smaller step? True, dist_mean=0.0110532
# Iter73, Smaller step? True, dist_mean=0.0108495
# Iter74, Smaller step? True, dist_mean=0.010651
# Iter75, Smaller step? True, dist_mean=0.0104573
# Iter76, Smaller step? True, dist_mean=0.0102682
# Iter77, Smaller step? True, dist_mean=0.0100835
# Iter78, Smaller step? True, dist_mean=0.0099031
# logm result may be inaccurate, approximate err = 3.7413536299869112e-06
# logm result may be inaccurate, approximate err = 2.157941644477262e-06
# logm result may be inaccurate, approximate err = 4.824267481158975e-06
# logm result may be inaccurate, approximate err = 5.486237334207746e-06
# logm result may be inaccurate, approximate err = 3.4010477360422094e-06
# logm result may be inaccurate, approximate err = 6.28232075083013e-06
# logm result may be inaccurate, approximate err = 3.2956080977622347e-06
# logm result may be inaccurate, approximate err = 5.568205296323789e-06
# logm result may be inaccurate, approximate err = 3.913177391134409e-06
# logm result may be inaccurate, approximate err = 5.736287029377353e-06
# logm result may be inaccurate, approximate err = 4.8357232118931545e-06
# logm result may be inaccurate, approximate err = 3.7466982100096372e-06
# logm result may be inaccurate, approximate err = 5.058759786730757e-06
# logm result may be inaccurate, approximate err = 1.8309108838937215e-06
# logm result may be inaccurate, approximate err = 5.593812473926122e-06
# logm result may be inaccurate, approximate err = 2.4472785419635756e-06
# logm result may be inaccurate, approximate err = 3.430994335657673e-06
# logm result may be inaccurate, approximate err = 9.895632789153714e-06
# logm result may be inaccurate, approximate err = 3.5845290222096192e-06
# logm result may be inaccurate, approximate err = 9.89696014390612e-06
# logm result may be inaccurate, approximate err = 4.396905161924569e-06
# logm result may be inaccurate, approximate err = 5.221720579668811e-06
# Iter0, Smaller step? NA, dist_mean=14.2981159
# Iter1, Smaller step? True, dist_mean=2.3138217
# Iter2, Smaller step? True, dist_mean=1.3884011
# Iter3, Smaller step? True, dist_mean=0.9586796
# Iter4, Smaller step? True, dist_mean=0.71418
# Iter5, Smaller step? True, dist_mean=0.5618339
# Iter6, Smaller step? True, dist_mean=0.4579967
# Iter7, Smaller step? True, dist_mean=0.3859637
# Iter8, Smaller step? True, dist_mean=0.3345401
# Iter9, Smaller step? True, dist_mean=0.2987807
# Iter10, Smaller step? True, dist_mean=0.2746458
# Iter11, Smaller step? True, dist_mean=0.2601038
# Iter12, Smaller step? True, dist_mean=0.2532791
# Iter13, Smaller step? True, dist_mean=0.2530153
# Iter14, Smaller step? False, dist_mean=0.2582561
# Fold 6 completed.
# Repetition 1 completed.
# logm result may be inaccurate, approximate err = 4.937755408848998e-06
# logm result may be inaccurate, approximate err = 4.71130347632866e-06
# logm result may be inaccurate, approximate err = 4.485021813138036e-06
# logm result may be inaccurate, approximate err = 3.6326052249718713e-06
# logm result may be inaccurate, approximate err = 5.2655577902887565e-06
# logm result may be inaccurate, approximate err = 3.3782571290813263e-06
# logm result may be inaccurate, approximate err = 4.896957059177924e-06
# logm result may be inaccurate, approximate err = 3.976087347955425e-06
# logm result may be inaccurate, approximate err = 3.122144257396477e-06
# logm result may be inaccurate, approximate err = 4.739379982067623e-06
# logm result may be inaccurate, approximate err = 5.994207622705469e-06
# logm result may be inaccurate, approximate err = 3.3210568167544407e-06
# logm result may be inaccurate, approximate err = 2.6429807512211113e-06
# logm result may be inaccurate, approximate err = 5.118094663283653e-06
# logm result may be inaccurate, approximate err = 3.2701493098717327e-06
# logm result may be inaccurate, approximate err = 4.440492138711155e-06
# logm result may be inaccurate, approximate err = 6.584562808973263e-06
# logm result may be inaccurate, approximate err = 4.114277479716693e-06
# logm result may be inaccurate, approximate err = 4.0074682374715086e-06
# logm result may be inaccurate, approximate err = 4.903684812114199e-06
# logm result may be inaccurate, approximate err = 4.074284831816238e-06
# logm result may be inaccurate, approximate err = 5.119516025411704e-06
# logm result may be inaccurate, approximate err = 4.6910502451844775e-06
# logm result may be inaccurate, approximate err = 5.692480094300142e-06
# logm result may be inaccurate, approximate err = 2.633465919208497e-06
# Iter0, Smaller step? NA, dist_mean=14.1872406
# Iter1, Smaller step? True, dist_mean=2.2114253
# Iter2, Smaller step? True, dist_mean=1.2825629
# Iter3, Smaller step? True, dist_mean=0.8562935
# Iter4, Smaller step? True, dist_mean=0.6189495
# Iter5, Smaller step? True, dist_mean=0.4730597
# Iter6, Smaller step? True, dist_mean=0.3741795
# Iter7, Smaller step? True, dist_mean=0.3046218
# Iter8, Smaller step? True, dist_mean=0.2531027
# Iter9, Smaller step? True, dist_mean=0.2142449
# Iter10, Smaller step? True, dist_mean=0.1839664
# Iter11, Smaller step? True, dist_mean=0.1601169
# Iter12, Smaller step? True, dist_mean=0.1409134
# Iter13, Smaller step? True, dist_mean=0.1253514
# Iter14, Smaller step? True, dist_mean=0.1125524
# Iter15, Smaller step? True, dist_mean=0.1019939
# Iter16, Smaller step? True, dist_mean=0.0932022
# Iter17, Smaller step? True, dist_mean=0.0858816
# Iter18, Smaller step? True, dist_mean=0.0797575
# Iter19, Smaller step? True, dist_mean=0.0746509
# Iter20, Smaller step? True, dist_mean=0.0703931
# Iter21, Smaller step? True, dist_mean=0.0668701
# Iter22, Smaller step? True, dist_mean=0.0639732
# Iter23, Smaller step? True, dist_mean=0.0616267
# Iter24, Smaller step? True, dist_mean=0.059758
# Iter25, Smaller step? True, dist_mean=0.0583148
# Iter26, Smaller step? True, dist_mean=0.0572474
# Iter27, Smaller step? True, dist_mean=0.0565187
# Iter28, Smaller step? True, dist_mean=0.0560936
# Iter29, Smaller step? True, dist_mean=0.0559454
# Iter30, Smaller step? False, dist_mean=0.0560489
# logm result may be inaccurate, approximate err = 3.456157082319177e-06
# logm result may be inaccurate, approximate err = 2.7122689248831722e-06
# logm result may be inaccurate, approximate err = 2.6103732902167434e-06
# logm result may be inaccurate, approximate err = 3.907856185371728e-06
# logm result may be inaccurate, approximate err = 1.594303258697503e-06
# logm result may be inaccurate, approximate err = 3.950496128624589e-06
# logm result may be inaccurate, approximate err = 6.431967686414625e-06
# logm result may be inaccurate, approximate err = 4.236650848956191e-06
# logm result may be inaccurate, approximate err = 3.2833182054200655e-06
# logm result may be inaccurate, approximate err = 4.202123459787805e-06
# logm result may be inaccurate, approximate err = 4.154326300257394e-06
# logm result may be inaccurate, approximate err = 3.891188504410932e-06
# logm result may be inaccurate, approximate err = 3.2652088949173904e-06
# logm result may be inaccurate, approximate err = 5.366845186256645e-06
# logm result may be inaccurate, approximate err = 3.462148497030561e-06
# logm result may be inaccurate, approximate err = 5.802563424104097e-06
# logm result may be inaccurate, approximate err = 5.255420247580235e-06
# logm result may be inaccurate, approximate err = 3.999299532975973e-06
# logm result may be inaccurate, approximate err = 3.5731623959769072e-06
# logm result may be inaccurate, approximate err = 3.4162882913141457e-06
# logm result may be inaccurate, approximate err = 5.628948279020851e-06
# Iter0, Smaller step? NA, dist_mean=14.1214654
# Iter1, Smaller step? True, dist_mean=2.3318135
# Iter2, Smaller step? True, dist_mean=1.4150853
# Iter3, Smaller step? True, dist_mean=0.9915287
# Iter4, Smaller step? True, dist_mean=0.7485887
# Iter5, Smaller step? True, dist_mean=0.5949187
# Iter6, Smaller step? True, dist_mean=0.487134
# Iter7, Smaller step? True, dist_mean=0.4091669
# Iter8, Smaller step? True, dist_mean=0.3495742
# Iter9, Smaller step? True, dist_mean=0.3036026
# Iter10, Smaller step? True, dist_mean=0.266971
# Iter11, Smaller step? True, dist_mean=0.2378347
# Iter12, Smaller step? True, dist_mean=0.2142881
# Iter13, Smaller step? True, dist_mean=0.1955084
# Iter14, Smaller step? True, dist_mean=0.1805786
# Iter15, Smaller step? True, dist_mean=0.1691141
# Iter16, Smaller step? True, dist_mean=0.1606699
# Iter17, Smaller step? True, dist_mean=0.1550686
# Iter18, Smaller step? True, dist_mean=0.1521004
# Iter19, Smaller step? True, dist_mean=0.1516797
# Iter20, Smaller step? False, dist_mean=0.1537106
# Fold 1 completed.
# logm result may be inaccurate, approximate err = 5.0814295154392634e-06
# logm result may be inaccurate, approximate err = 3.1630521257055413e-06
# logm result may be inaccurate, approximate err = 5.039770945079493e-06
# logm result may be inaccurate, approximate err = 4.101299830969691e-06
# logm result may be inaccurate, approximate err = 5.878819004591584e-06
# logm result may be inaccurate, approximate err = 5.4999397009483416e-06
# logm result may be inaccurate, approximate err = 5.053394464928995e-06
# logm result may be inaccurate, approximate err = 3.2927624265790642e-06
# logm result may be inaccurate, approximate err = 1.983922710762589e-06
# logm result may be inaccurate, approximate err = 4.8445222752968405e-06
# logm result may be inaccurate, approximate err = 3.028851998997435e-06
# logm result may be inaccurate, approximate err = 3.9395378968510474e-06
# logm result may be inaccurate, approximate err = 7.728040657808669e-06
# logm result may be inaccurate, approximate err = 4.695634535987872e-06
# logm result may be inaccurate, approximate err = 4.367538299422731e-06
# logm result may be inaccurate, approximate err = 7.61050898967556e-06
# logm result may be inaccurate, approximate err = 4.315993198614819e-06
# logm result may be inaccurate, approximate err = 4.4006091887984824e-06
# logm result may be inaccurate, approximate err = 3.382510610642813e-06
# logm result may be inaccurate, approximate err = 4.668573370764461e-06
# logm result may be inaccurate, approximate err = 4.8989495831390055e-06
# logm result may be inaccurate, approximate err = 4.378884620924913e-06
# logm result may be inaccurate, approximate err = 3.846870693487451e-06
# logm result may be inaccurate, approximate err = 3.90278839126596e-06
# logm result may be inaccurate, approximate err = 2.6455377514314724e-06
# Iter0, Smaller step? NA, dist_mean=14.197582
# Iter1, Smaller step? True, dist_mean=2.1900628
# Iter2, Smaller step? True, dist_mean=1.2762704
# Iter3, Smaller step? True, dist_mean=0.8503416
# Iter4, Smaller step? True, dist_mean=0.6102012
# Iter5, Smaller step? True, dist_mean=0.4614427
# Iter6, Smaller step? True, dist_mean=0.3600368
# Iter7, Smaller step? True, dist_mean=0.288277
# Iter8, Smaller step? True, dist_mean=0.2348132
# Iter9, Smaller step? True, dist_mean=0.1942423
# Iter10, Smaller step? True, dist_mean=0.1624516
# Iter11, Smaller step? True, dist_mean=0.1372712
# Iter12, Smaller step? True, dist_mean=0.1168918
# Iter13, Smaller step? True, dist_mean=0.1002808
# Iter14, Smaller step? True, dist_mean=0.0865339
# Iter15, Smaller step? True, dist_mean=0.0750989
# Iter16, Smaller step? True, dist_mean=0.0654804
# Iter17, Smaller step? True, dist_mean=0.0573574
# Iter18, Smaller step? True, dist_mean=0.0504389
# Iter19, Smaller step? True, dist_mean=0.0445267
# Iter20, Smaller step? True, dist_mean=0.0394405
# Iter21, Smaller step? True, dist_mean=0.0350522
# Iter22, Smaller step? True, dist_mean=0.0312454
# Iter23, Smaller step? True, dist_mean=0.0279345
# Iter24, Smaller step? True, dist_mean=0.0250418
# Iter25, Smaller step? True, dist_mean=0.0225085
# Iter26, Smaller step? True, dist_mean=0.0202814
# Iter27, Smaller step? True, dist_mean=0.0183191
# Iter28, Smaller step? True, dist_mean=0.0165844
# Iter29, Smaller step? True, dist_mean=0.0150476
# Iter30, Smaller step? True, dist_mean=0.0136823
# Iter31, Smaller step? True, dist_mean=0.0124668
# Iter32, Smaller step? True, dist_mean=0.0113818
# Iter33, Smaller step? True, dist_mean=0.0104116
# Iter34, Smaller step? True, dist_mean=0.0095419
# logm result may be inaccurate, approximate err = 4.7759190409051884e-06
# logm result may be inaccurate, approximate err = 1.9339223463396164e-06
# logm result may be inaccurate, approximate err = 6.458214793398226e-06
# logm result may be inaccurate, approximate err = 4.9110768524232604e-06
# logm result may be inaccurate, approximate err = 1.7346501867314024e-06
# ...
# Iter12, Smaller step? True, dist_mean=0.1141306
# Iter13, Smaller step? True, dist_mean=0.0974
# Iter14, Smaller step? True, dist_mean=0.0836337
# Iter15, Smaller step? True, dist_mean=0.0722618
# Iter16, Smaller step? True, dist_mean=0.0627799
# Iter17, Smaller step? True, dist_mean=0.0548502
# Iter18, Smaller step? True, dist_mean=0.0481711
# Iter19, Smaller step? True, dist_mean=0.0425303
# Iter20, Smaller step? True, dist_mean=0.0377376
# Iter21, Smaller step? True, dist_mean=0.0336544
# Iter22, Smaller step? True, dist_mean=0.0301565
# Iter23, Smaller step? True, dist_mean=0.0271507
# Iter24, Smaller step? True, dist_mean=0.0245538
# Iter25, Smaller step? True, dist_mean=0.0223024
# Iter26, Smaller step? True, dist_mean=0.0203397
# Iter27, Smaller step? True, dist_mean=0.018622
# Iter28, Smaller step? True, dist_mean=0.0171104
# Iter29, Smaller step? True, dist_mean=0.0157745
# Iter30, Smaller step? True, dist_mean=0.0145874
# Iter31, Smaller step? True, dist_mean=0.013528
# Iter32, Smaller step? True, dist_mean=0.0125776
# Iter33, Smaller step? True, dist_mean=0.0117213
# Iter34, Smaller step? True, dist_mean=0.0109461
# Iter35, Smaller step? True, dist_mean=0.0102416
# Iter36, Smaller step? True, dist_mean=0.0095985
# logm result may be inaccurate, approximate err = 6.807788805477371e-06
# logm result may be inaccurate, approximate err = 2.6650929471391193e-06
# logm result may be inaccurate, approximate err = 8.345720140620053e-06
# logm result may be inaccurate, approximate err = 3.923124929133572e-06
# logm result may be inaccurate, approximate err = 2.463491264634816e-06
# logm result may be inaccurate, approximate err = 3.260284552870868e-06
# logm result may be inaccurate, approximate err = 7.880973474920282e-06
# logm result may be inaccurate, approximate err = 3.787205318016314e-06
# logm result may be inaccurate, approximate err = 5.198695613742533e-06
# logm result may be inaccurate, approximate err = 7.357638688143436e-06
# logm result may be inaccurate, approximate err = 3.4390044711498217e-06
# logm result may be inaccurate, approximate err = 5.512976705043283e-06
# logm result may be inaccurate, approximate err = 3.2319191788812622e-06
# logm result may be inaccurate, approximate err = 3.91783190618433e-06
# logm result may be inaccurate, approximate err = 5.385935063880863e-06
# logm result may be inaccurate, approximate err = 2.1915029625485386e-06
# logm result may be inaccurate, approximate err = 7.669267075305487e-06
# logm result may be inaccurate, approximate err = 3.6017126092655546e-06
# logm result may be inaccurate, approximate err = 4.634642082470243e-06
# logm result may be inaccurate, approximate err = 3.6153328408279883e-06
# logm result may be inaccurate, approximate err = 3.605599599651076e-06
# logm result may be inaccurate, approximate err = 5.104938167746672e-06
# Iter0, Smaller step? NA, dist_mean=14.1634483
# Iter1, Smaller step? True, dist_mean=2.3254226
# Iter2, Smaller step? True, dist_mean=1.3944351
# Iter3, Smaller step? True, dist_mean=0.9636365
# Iter4, Smaller step? True, dist_mean=0.7167866
# Iter5, Smaller step? True, dist_mean=0.5611043
# Iter6, Smaller step? True, dist_mean=0.4527816
# Iter7, Smaller step? True, dist_mean=0.3756128
# Iter8, Smaller step? True, dist_mean=0.3184817
# Iter9, Smaller step? True, dist_mean=0.2767617
# Iter10, Smaller step? True, dist_mean=0.2465971
# Iter11, Smaller step? True, dist_mean=0.226276
# Iter12, Smaller step? True, dist_mean=0.2141485
# Iter13, Smaller step? True, dist_mean=0.2092762
# Iter14, Smaller step? False, dist_mean=0.2106418
# Fold 4 completed.
# logm result may be inaccurate, approximate err = 6.814236339879738e-06
# logm result may be inaccurate, approximate err = 2.6741932860434737e-06
# logm result may be inaccurate, approximate err = 4.782836490251521e-06
# logm result may be inaccurate, approximate err = 3.6975513667959128e-06
# logm result may be inaccurate, approximate err = 2.8205763899415868e-06
# logm result may be inaccurate, approximate err = 3.9693280844299294e-06
# logm result may be inaccurate, approximate err = 3.1010299801404245e-06
# logm result may be inaccurate, approximate err = 2.9579412679006573e-06
# logm result may be inaccurate, approximate err = 4.855751130194008e-06
# logm result may be inaccurate, approximate err = 3.1658851117567777e-06
# logm result may be inaccurate, approximate err = 4.36703618263862e-06
# logm result may be inaccurate, approximate err = 5.98594647755587e-06
# logm result may be inaccurate, approximate err = 4.832133904022018e-06
# logm result may be inaccurate, approximate err = 4.718712428463199e-06
# logm result may be inaccurate, approximate err = 4.383823425910261e-06
# logm result may be inaccurate, approximate err = 3.0596789063204703e-06
# logm result may be inaccurate, approximate err = 7.147626608251552e-06
# logm result may be inaccurate, approximate err = 5.107275760115524e-06
# logm result may be inaccurate, approximate err = 3.264089668502724e-06
# logm result may be inaccurate, approximate err = 5.723417275540369e-06
# logm result may be inaccurate, approximate err = 5.930835492758447e-06
# logm result may be inaccurate, approximate err = 3.7157009017346237e-06
# logm result may be inaccurate, approximate err = 3.0536380494839715e-06
# logm result may be inaccurate, approximate err = 5.069539220359863e-06
# logm result may be inaccurate, approximate err = 3.118098969250306e-06
# Iter0, Smaller step? NA, dist_mean=14.2195899
# Iter1, Smaller step? True, dist_mean=2.1754484
# Iter2, Smaller step? True, dist_mean=1.2696216
# Iter3, Smaller step? True, dist_mean=0.8514073
# Iter4, Smaller step? True, dist_mean=0.6177052
# Iter5, Smaller step? True, dist_mean=0.4745374
# Iter6, Smaller step? True, dist_mean=0.3782759
# Iter7, Smaller step? True, dist_mean=0.3113009
# Iter8, Smaller step? True, dist_mean=0.2621886
# Iter9, Smaller step? True, dist_mean=0.2254636
# Iter10, Smaller step? True, dist_mean=0.1969424
# Iter11, Smaller step? True, dist_mean=0.1744535
# Iter12, Smaller step? True, dist_mean=0.1561843
# Iter13, Smaller step? True, dist_mean=0.1411592
# Iter14, Smaller step? True, dist_mean=0.1285074
# Iter15, Smaller step? True, dist_mean=0.1177535
# Iter16, Smaller step? True, dist_mean=0.1084445
# Iter17, Smaller step? True, dist_mean=0.1003321
# Iter18, Smaller step? True, dist_mean=0.0931639
# Iter19, Smaller step? True, dist_mean=0.0868017
# Iter20, Smaller step? True, dist_mean=0.0810955
# Iter21, Smaller step? True, dist_mean=0.0759635
# Iter22, Smaller step? True, dist_mean=0.0713114
# Iter23, Smaller step? True, dist_mean=0.0670882
# Iter24, Smaller step? True, dist_mean=0.0632317
# Iter25, Smaller step? True, dist_mean=0.0597081
# Iter26, Smaller step? True, dist_mean=0.0564747
# Iter27, Smaller step? True, dist_mean=0.0535084
# Iter28, Smaller step? True, dist_mean=0.0507787
# Iter29, Smaller step? True, dist_mean=0.0482692
# Iter30, Smaller step? True, dist_mean=0.0459576
# Iter31, Smaller step? True, dist_mean=0.0438317
# Iter32, Smaller step? True, dist_mean=0.0418747
# Iter33, Smaller step? True, dist_mean=0.0400774
# Iter34, Smaller step? True, dist_mean=0.038427
# Iter35, Smaller step? True, dist_mean=0.0369161
# Iter36, Smaller step? True, dist_mean=0.0355345
# Iter37, Smaller step? True, dist_mean=0.0342762
# Iter38, Smaller step? True, dist_mean=0.033133
# Iter39, Smaller step? True, dist_mean=0.0320997
# Iter40, Smaller step? True, dist_mean=0.0311694
# Iter41, Smaller step? True, dist_mean=0.0303375
# Iter42, Smaller step? True, dist_mean=0.0295979
# Iter43, Smaller step? True, dist_mean=0.0289464
# Iter44, Smaller step? True, dist_mean=0.0283775
# Iter45, Smaller step? True, dist_mean=0.0278872
# Iter46, Smaller step? True, dist_mean=0.0274706
# Iter47, Smaller step? True, dist_mean=0.0271236
# Iter48, Smaller step? True, dist_mean=0.0268417
# Iter49, Smaller step? True, dist_mean=0.0266212
# Iter50, Smaller step? True, dist_mean=0.0264578
# Iter51, Smaller step? True, dist_mean=0.0263481
# Iter52, Smaller step? False, dist_mean=0.0262881
# logm result may be inaccurate, approximate err = 3.895365372291648e-06
# logm result may be inaccurate, approximate err = 2.286297739511802e-06
# logm result may be inaccurate, approximate err = 3.341104032031224e-06
# logm result may be inaccurate, approximate err = 3.818882835557655e-06
# logm result may be inaccurate, approximate err = 4.219780282694016e-06
# logm result may be inaccurate, approximate err = 2.0932237278482204e-06
# logm result may be inaccurate, approximate err = 4.767080872233576e-06
# logm result may be inaccurate, approximate err = 5.640547716676514e-06
# logm result may be inaccurate, approximate err = 3.858986268984938e-06
# logm result may be inaccurate, approximate err = 4.802957178579172e-06
# logm result may be inaccurate, approximate err = 3.957140833280104e-06
# logm result may be inaccurate, approximate err = 5.006255608797727e-06
# logm result may be inaccurate, approximate err = 6.820828196967335e-06
# logm result may be inaccurate, approximate err = 7.760331162600103e-06
# logm result may be inaccurate, approximate err = 2.87999468186853e-06
# logm result may be inaccurate, approximate err = 5.497084764562323e-06
# logm result may be inaccurate, approximate err = 3.4866274123677712e-06
# logm result may be inaccurate, approximate err = 2.699717667074732e-06
# logm result may be inaccurate, approximate err = 3.020646244451068e-06
# logm result may be inaccurate, approximate err = 4.175256108037978e-06
# logm result may be inaccurate, approximate err = 3.885596137882855e-06
# logm result may be inaccurate, approximate err = 5.088153279400804e-06
# Iter0, Smaller step? NA, dist_mean=14.3268687
# Iter1, Smaller step? True, dist_mean=2.3283798
# Iter2, Smaller step? True, dist_mean=1.3935632
# Iter3, Smaller step? True, dist_mean=0.9649749
# Iter4, Smaller step? True, dist_mean=0.7246849
# Iter5, Smaller step? True, dist_mean=0.5771972
# Iter6, Smaller step? True, dist_mean=0.4783342
# Iter7, Smaller step? True, dist_mean=0.411153
# Iter8, Smaller step? True, dist_mean=0.3645113
# Iter9, Smaller step? True, dist_mean=0.3336001
# Iter10, Smaller step? True, dist_mean=0.3146872
# Iter11, Smaller step? True, dist_mean=0.306159
# Iter12, Smaller step? False, dist_mean=0.3067578
# Fold 5 completed.
# logm result may be inaccurate, approximate err = 4.7558523109995815e-06
# logm result may be inaccurate, approximate err = 3.98535486863706e-06
# logm result may be inaccurate, approximate err = 3.5722553051856735e-06
# logm result may be inaccurate, approximate err = 4.6567873762049515e-06
# logm result may be inaccurate, approximate err = 2.8595371630364615e-06
# logm result may be inaccurate, approximate err = 2.9243174057473444e-06
# logm result may be inaccurate, approximate err = 4.745353224018263e-06
# logm result may be inaccurate, approximate err = 5.929469120202181e-06
# logm result may be inaccurate, approximate err = 5.375810731561411e-06
# logm result may be inaccurate, approximate err = 3.7698514959784666e-06
# logm result may be inaccurate, approximate err = 2.7374795920414696e-06
# logm result may be inaccurate, approximate err = 4.413931353445086e-06
# logm result may be inaccurate, approximate err = 3.6305393051720578e-06
# logm result may be inaccurate, approximate err = 3.1559591108803472e-06
# logm result may be inaccurate, approximate err = 3.0624751444017002e-06
# logm result may be inaccurate, approximate err = 3.704507360081515e-06
# logm result may be inaccurate, approximate err = 2.6856215084908343e-06
# logm result may be inaccurate, approximate err = 4.286332679528151e-06
# logm result may be inaccurate, approximate err = 3.305955979364908e-06
# logm result may be inaccurate, approximate err = 4.643360423872175e-06
# logm result may be inaccurate, approximate err = 4.928533689893682e-06
# logm result may be inaccurate, approximate err = 4.009928812275476e-06
# logm result may be inaccurate, approximate err = 4.018259538619092e-06
# logm result may be inaccurate, approximate err = 5.333769996213144e-06
# logm result may be inaccurate, approximate err = 2.9307785842898545e-06
# Iter0, Smaller step? NA, dist_mean=14.2122222
# Iter1, Smaller step? True, dist_mean=2.2068133
# Iter2, Smaller step? True, dist_mean=1.273556
# Iter3, Smaller step? True, dist_mean=0.8415007
# Iter4, Smaller step? True, dist_mean=0.5992299
# Iter5, Smaller step? True, dist_mean=0.4494828
# Iter6, Smaller step? True, dist_mean=0.3477647
# Iter7, Smaller step? True, dist_mean=0.2760741
# Iter8, Smaller step? True, dist_mean=0.2230832
# Iter9, Smaller step? True, dist_mean=0.1832228
# Iter10, Smaller step? True, dist_mean=0.1523644
# Iter11, Smaller step? True, dist_mean=0.1282209
# Iter12, Smaller step? True, dist_mean=0.1089554
# Iter13, Smaller step? True, dist_mean=0.0934651
# Iter14, Smaller step? True, dist_mean=0.0808255
# Iter15, Smaller step? True, dist_mean=0.0704488
# Iter16, Smaller step? True, dist_mean=0.0618292
# Iter17, Smaller step? True, dist_mean=0.0546311
# Iter18, Smaller step? True, dist_mean=0.048561
# Iter19, Smaller step? True, dist_mean=0.0434172
# Iter20, Smaller step? True, dist_mean=0.0390215
# Iter21, Smaller step? True, dist_mean=0.035248
# Iter22, Smaller step? True, dist_mean=0.0319845
# Iter23, Smaller step? True, dist_mean=0.0291498
# Iter24, Smaller step? True, dist_mean=0.0266712
# Iter25, Smaller step? True, dist_mean=0.024495
# Iter26, Smaller step? True, dist_mean=0.022573
# Iter27, Smaller step? True, dist_mean=0.0208687
# Iter28, Smaller step? True, dist_mean=0.0193494
# Iter29, Smaller step? True, dist_mean=0.01799
# Iter30, Smaller step? True, dist_mean=0.0167679
# Iter31, Smaller step? True, dist_mean=0.0156654
# Iter32, Smaller step? True, dist_mean=0.0146667
# Iter33, Smaller step? True, dist_mean=0.0137591
# Iter34, Smaller step? True, dist_mean=0.0129313
# Iter35, Smaller step? True, dist_mean=0.0121742
# Iter36, Smaller step? True, dist_mean=0.0114795
# Iter37, Smaller step? True, dist_mean=0.0108405
# Iter38, Smaller step? True, dist_mean=0.010251
# Iter39, Smaller step? True, dist_mean=0.0097061
# logm result may be inaccurate, approximate err = 3.416330130628883e-06
# logm result may be inaccurate, approximate err = 1.8721889306849734e-06
# logm result may be inaccurate, approximate err = 3.592101782085851e-06
# logm result may be inaccurate, approximate err = 3.891699627307782e-06
# logm result may be inaccurate, approximate err = 4.45676541044913e-06
# logm result may be inaccurate, approximate err = 4.886861056939097e-06
# logm result may be inaccurate, approximate err = 7.115869278310203e-06
# logm result may be inaccurate, approximate err = 6.023785814444595e-06
# logm result may be inaccurate, approximate err = 3.951463940161374e-06
# logm result may be inaccurate, approximate err = 3.3406508544455832e-06
# logm result may be inaccurate, approximate err = 3.7031705786777307e-06
# logm result may be inaccurate, approximate err = 4.00811910727667e-06
# logm result may be inaccurate, approximate err = 4.642827469242658e-06
# logm result may be inaccurate, approximate err = 5.605549262483138e-06
# logm result may be inaccurate, approximate err = 2.5544183853752108e-06
# logm result may be inaccurate, approximate err = 4.274588033717808e-06
# logm result may be inaccurate, approximate err = 3.260293764824942e-06
# logm result may be inaccurate, approximate err = 4.798354541094176e-06
# logm result may be inaccurate, approximate err = 3.201702512177097e-06
# logm result may be inaccurate, approximate err = 5.506514793844523e-06
# logm result may be inaccurate, approximate err = 2.7019952902776915e-06
# logm result may be inaccurate, approximate err = 6.9550387080578605e-06
# Iter0, Smaller step? NA, dist_mean=14.2778828
# Iter1, Smaller step? True, dist_mean=2.2941953
# Iter2, Smaller step? True, dist_mean=1.3683066
# Iter3, Smaller step? True, dist_mean=0.9395474
# Iter4, Smaller step? True, dist_mean=0.6983971
# Iter5, Smaller step? True, dist_mean=0.5503683
# Iter6, Smaller step? True, dist_mean=0.4513376
# Iter7, Smaller step? True, dist_mean=0.3843207
# Iter8, Smaller step? True, dist_mean=0.3381958
# Iter9, Smaller step? True, dist_mean=0.3080089
# Iter10, Smaller step? True, dist_mean=0.2897615
# Iter11, Smaller step? True, dist_mean=0.2813469
# Iter12, Smaller step? True, dist_mean=0.2808415
# Iter13, Smaller step? False, dist_mean=0.2869999
# Fold 6 completed.
# Repetition 10 completed.

# %%
np.mean(accuracy)
np.mean(execution_time)
# Out:
# 0.78148156
# 155.51178

# %%
rows = ['Rep{}'.format(i+1) for i in list(range(repetition))]
cols = ['Fold{}'.format(i+1) for i in list(range(k))]

accuracy_df = pd.DataFrame(accuracy, index=rows, columns=cols)
execution_time_df = pd.DataFrame(execution_time, index=rows, columns=cols)

# %%
save_dir = "D:/Projects/BW Revision/Results/BCI III IVa/"
accuracy_df.to_csv(save_dir+subject+"_accuracy_"+method+".csv")
execution_time_df.to_csv(save_dir+"Execution Time/"+subject+"_execution_time_"+method+".csv")
